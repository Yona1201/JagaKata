# %%
# !pip install -q google-api-python-client pandas

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---
YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"

video_url = "https://youtu.be/HiTNW0U9ywg?si=_ICY5zDeiXJ4gqME"

max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments1.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: HiTNW0U9ywg...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments1.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---
YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"

video_url = "https://youtu.be/zqH6PZhTRcE?si=WxGsUlmvxxfykhWG"

max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments2.csv"

def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: zqH6PZhTRcE...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments2.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/3g6juOekPY0?si=98rN9Ro5JuDr8yHL"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments3.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: 3g6juOekPY0...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments3.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/jq7zj8jJFso?si=ttxcZ6sB9640tlej"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments4.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: jq7zj8jJFso...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments4.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/1PToDAUKA3E?si=bfT92NkiXfsjZgM6"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments5.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: 1PToDAUKA3E...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments5.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/aFx3uoYCC3w?si=NZAhJcoW_jpS1asi"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments6.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: aFx3uoYCC3w...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments6.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/h2yvge1tHKg?si=L_f_rzchF1BK0Q2i"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments7.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: h2yvge1tHKg...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments7.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/80BP6eNRSnI?si=8pFr_0nrblKzYT5r"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments8.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: 80BP6eNRSnI...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments8.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/EGHl0D-YvDc?si=53ax6HK1k_Zj3Uw7"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments9.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: EGHl0D-YvDc...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments9.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/mMFL1P6o3Aw?si=GVMy8vXp6xXB6shC"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments10.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: mMFL1P6o3Aw...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments10.csv

# %%
import os
import pandas as pd
import re
from googleapiclient.discovery import build

# --- KONFIGURASI ---

YOUTUBE_API_KEY = "AIzaSyCoTeeIp7Z4VAS8_vDoVQg2gVfah-PlI8o"


video_url = "https://youtu.be/sWsDZtCY-dc?si=o3NfvwXAHHTeEHmi"


max_comments_to_fetch = 100

# NAMA FILE OUTPUT
output_csv_file = "youtube_comments11.csv"


def extract_video_id(url):
    """Fungsi untuk mengekstrak ID video dari berbagai format URL YouTube."""
    patterns = [
        r"(?:https?:\/\/)?(?:www\.)?youtu\.be\/([^\s\/\?\&]+)",
        r"(?:https?:\/\/)?(?:www\.)?youtube\.com\/watch\?v=([^\s\&]+)"
    ]
    for pattern in patterns:
        match = re.search(pattern, url)
        if match:
            return match.group(1)
    return None

def get_youtube_comments(api_key, video_id, max_results):
    """Fungsi untuk mengambil komentar dari video YouTube."""
    comments = []
    try:
        youtube = build("youtube", "v3", developerKey=api_key)

        # Mengambil komentar dari video
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # API mengizinkan maksimal 100 per halaman
            textFormat="plainText"
        )

        print(f"Mengambil komentar dari video ID: {video_id}...")

        # Loop untuk mengambil beberapa halaman jika diperlukan (paginasi)
        while request and len(comments) < max_results:
            response = request.execute()
            items = response.get("items", [])

            for item in items:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
                if len(comments) >= max_results:
                    break

            # Cek apakah ada halaman berikutnya
            if 'nextPageToken' in response and len(comments) < max_results:
                request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)
            else:
                break

        print(f"Berhasil mengumpulkan {len(comments)} komentar.")
        return comments

    except Exception as e:
        print(f"Terjadi error: {e}")
        return comments

# --- EKSEKUSI ---
video_id = extract_video_id(video_url)
if video_id:
    # Ambil komentar menggunakan fungsi
    comment_list = get_youtube_comments(YOUTUBE_API_KEY, video_id, max_comments_to_fetch)

    # Simpan ke dalam DataFrame Pandas
    if comment_list:
        df = pd.DataFrame(comment_list, columns=['text_asli'])
        df['sumber_url'] = video_url # Menambahkan kolom sumber URL

        # Simpan ke file CSV
        df.to_csv(output_csv_file, index=False)
        print(f"Data berhasil disimpan ke file: {output_csv_file}")
    else:
        print("Tidak ada komentar untuk disimpan.")
else:
    print("URL Video tidak valid.")
# Out:
# Mengambil komentar dari video ID: sWsDZtCY-dc...
# Berhasil mengumpulkan 100 komentar.
# Data berhasil disimpan ke file: youtube_comments11.csv
